# %% [markdown]
# # World 3-1: Jupyter Test
#
# Welcome to the science lab! Testing cells below.

# %%
print('Hello from Jupyter!')
# Out:
# Hello from Jupyter!

# %% [markdown]
# ## Output Test

# %%
20 + 22
# Out:
# 42
